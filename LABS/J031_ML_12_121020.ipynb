# %% [markdown]
# <a href="https://colab.research.google.com/github/rohitsmittal7/ML_J031_SEMV/blob/main/LABS/J031_ML_12_121020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Analysis on air quality

# %%
import numpy as np
import pandas as pd

# %%
# !wget -O AirQualityUCI.zip https://archive.ics.uci.edu/ml/machine-learning-databases/00360/AirQualityUCI.zip
# !unzip AirQualityUCI.zip
df = pd.read_excel('/content/AirQualityUCI.xlsx', parse_dates=[['Date', 'Time']])
df.replace(to_replace=-200.0, value=0.0, inplace=True)
wv = df['NMHC(GT)']
bad_wv = wv == -200.0
wv[bad_wv] = 0.0
# Out:
# --2020-11-03 08:25:31--  https://archive.ics.uci.edu/ml/machine-learning-databases/00360/AirQualityUCI.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1543989 (1.5M) [application/x-httpd-php]
# Saving to: ‘AirQualityUCI.zip’
#
# AirQualityUCI.zip   100%[===================>]   1.47M  1.38MB/s    in 1.1s
#
# 2020-11-03 08:25:32 (1.38 MB/s) - ‘AirQualityUCI.zip’ saved [1543989/1543989]
#
# Archive:  AirQualityUCI.zip
#   inflating: AirQualityUCI.csv
#   inflating: AirQualityUCI.xlsx
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
target = 'NO2(GT)'
target
# Out:
# 'NO2(GT)'

# %%
df.corr()[['NO2(GT)']]
# Out:
#                 NO2(GT)
# CO(GT)         0.723154
# PT08.S1(CO)    0.284508
# NMHC(GT)       0.099541
# C6H6(GT)       0.402581
# PT08.S2(NMHC)  0.334108
# NOx(GT)        0.795888
# PT08.S3(NOx)  -0.440202
# NO2(GT)        1.000000
# PT08.S4(NO2)   0.010185
# PT08.S5(O3)    0.439057
# T             -0.195697
# RH            -0.125245
# AH            -0.324221

# %%
df.head()
df = df[['CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)','PT08.S2(NMHC)', 'NOx(GT)','NO2(GT)','PT08.S5(O3)']]

# %%
df.head()
# Out:
#    CO(GT)  PT08.S1(CO)  NMHC(GT)  PT08.S2(NMHC)  NOx(GT)  NO2(GT)  PT08.S5(O3)
# 0     2.6      1360.00       150        1045.50    166.0    113.0      1267.50
# 1     2.0      1292.25       112         954.75    103.0     92.0       972.25
# 2     2.2      1402.00        88         939.25    131.0    114.0      1074.00
# 3     2.2      1375.50        80         948.25    172.0    122.0      1203.25
# 4     1.6      1272.25        51         835.50    131.0    116.0      1110.00

# %%
X = df.drop(target,axis=1)
y = df[[target]]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y)
value = y_test

# %%
print (x_train.shape)
print (x_test.shape)
print (y_train.shape)
print (y_test.shape)
# Out:
# (7017, 6)
# (2340, 6)
# (7017, 1)
# (2340, 1)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaler.fit(x_train)
x_train = scaler.fit_transform(x_train)
scaler.fit(x_test)
x_test = scaler.fit_transform(x_test)
scaler.fit(y_train)
y_train = scaler.fit_transform(y_train)
scaler.fit(y_test)
y_test = scaler.fit_transform(y_test)

# %%
x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))
x_test = np.reshape(x_test, (x_test.shape[0],x_test.shape[1],1))
print (x_train.shape)
print (x_test.shape)
# Out:
# (7017, 6, 1)
# (2340, 6, 1)

# %%
print (y_train.shape)
print (y_test.shape)
# Out:
# (7017, 1)
# (2340, 1)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Flatten
def RNN_MODEL():
    # have to convert to 3D for feeding the data
    regressor = Sequential()
    regressor.add(LSTM(units = 50,return_sequences = True))
    regressor.add(Dropout(0.2))
    regressor.add(LSTM(units = 50,return_sequences = True))
    regressor.add(Dropout(0.2))
    regressor.add(LSTM(units = 50))
    regressor.add(Dropout(0.2))
    regressor.add(Dense(units = 1))
    regressor.compile(optimizer = 'adam',loss = 'mean_squared_error',metrics=['accuracy'])
    return regressor

# %%
regressor = RNN_MODEL()

# %%
regressor.fit(x_train,y_train,epochs = 50)
# Out:
# Epoch 1/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0310 - accuracy: 0.1779
# Epoch 2/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0256 - accuracy: 0.1776
# Epoch 3/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0236 - accuracy: 0.1770
# Epoch 4/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0211 - accuracy: 0.1770
# Epoch 5/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0200 - accuracy: 0.1770
# Epoch 6/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0189 - accuracy: 0.1771
# Epoch 7/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0183 - accuracy: 0.1769
# Epoch 8/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0180 - accuracy: 0.1771
# Epoch 9/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0173 - accuracy: 0.1773
# Epoch 10/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0166 - accuracy: 0.1767
# Epoch 11/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0157 - accuracy: 0.1779
# Epoch 12/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0150 - accuracy: 0.1780
# Epoch 13/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0138 - accuracy: 0.1779
# Epoch 14/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0133 - accuracy: 0.1780
# Epoch 15/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0130 - accuracy: 0.1780
# Epoch 16/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0122 - accuracy: 0.1779
# Epoch 17/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0120 - accuracy: 0.1780
# Epoch 18/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0111 - accuracy: 0.1780
# Epoch 19/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0106 - accuracy: 0.1780
# Epoch 20/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0102 - accuracy: 0.1780
# Epoch 21/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0100 - accuracy: 0.1780
# Epoch 22/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0093 - accuracy: 0.1780
# Epoch 23/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0089 - accuracy: 0.1780
# Epoch 24/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0086 - accuracy: 0.1780
# Epoch 25/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0083 - accuracy: 0.1780
# Epoch 26/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0081 - accuracy: 0.1780
# Epoch 27/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0078 - accuracy: 0.1780
# Epoch 28/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0077 - accuracy: 0.1780
# Epoch 29/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0075 - accuracy: 0.1780
# Epoch 30/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0073 - accuracy: 0.1780
# Epoch 31/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0071 - accuracy: 0.1780
# Epoch 32/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0071 - accuracy: 0.1780
# Epoch 33/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0072 - accuracy: 0.1780
# Epoch 34/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0069 - accuracy: 0.1780
# Epoch 35/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0069 - accuracy: 0.1780
# Epoch 36/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0068 - accuracy: 0.1780
# Epoch 37/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0067 - accuracy: 0.1780
# Epoch 38/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0066 - accuracy: 0.1780
# Epoch 39/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0066 - accuracy: 0.1780
# Epoch 40/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0065 - accuracy: 0.1780
# Epoch 41/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0065 - accuracy: 0.1780
# Epoch 42/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0067 - accuracy: 0.1780
# Epoch 43/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0064 - accuracy: 0.1780
# Epoch 44/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0064 - accuracy: 0.1780
# Epoch 45/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0064 - accuracy: 0.1780
# Epoch 46/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0063 - accuracy: 0.1780
# Epoch 47/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0063 - accuracy: 0.1780
# Epoch 48/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0062 - accuracy: 0.1780
# Epoch 49/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0062 - accuracy: 0.1780
# Epoch 50/50
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0061 - accuracy: 0.1780

# %%
regressor.evaluate(x_test,y_test)
# Out:
# 74/74 [==============================] - 0s 3ms/step - loss: 0.0059 - accuracy: 0.1688
# [0.005884264595806599, 0.16880342364311218]

# %%
y_pred = regressor.predict(x_test)

# %%
y_pred
# Out:
# array([[0.254958  ],
#        [0.17993817],
#        [0.33400688],
#        ...,
#        [0.29678097],
#        [0.26761803],
#        [0.44698524]], dtype=float32)

# %%
output = scaler.inverse_transform(y_pred)
real_output = []
for item in output:
    real_output.append((item[0]))

# %%
real_output
# Out:
# [86.60924,
#  61.124996,
#  113.462135,
#  86.3859,
#  156.62692,
#  150.85454,
#  49.48915,
#  173.69672,
#  146.39964,
#  69.05768,
#  0.19211015,
#  -6.2965684,
#  104.03819,
#  150.57918,
#  -5.4455476,
#  139.6594,
#  100.692,
#  137.51503,
#  37.030014,
#  122.313835,
#  134.71848,
#  120.92875,
#  155.67151,
#  107.1885,
#  124.467834,
#  191.31976,
#  71.37798,
#  120.12727,
#  157.58582,
#  101.544495,
#  94.583954,
#  113.911804,
#  35.053898,
#  112.3569,
#  177.9814,
#  116.24521,
#  117.73984,
#  166.6362,
#  104.48349,
#  152.25931,
#  241.99875,
#  152.09213,
#  -0.91473025,
#  154.37935,
#  119.1023,
#  176.04411,
#  98.97918,
#  -3.9373672,
#  2.5934567,
#  95.1146,
#  90.84909,
#  131.11513,
#  127.2707,
#  159.48335,
#  119.48579,
#  -3.1874735,
#  117.005775,
#  104.488815,
#  -6.04086,
#  56.261555,
#  219.98358,
#  123.33476,
#  93.8071,
#  154.6368,
#  153.19778,
#  98.17415,
#  94.21362,
#  129.29453,
#  115.79811,
#  120.00341,
#  -6.2861204,
#  238.87167,
#  128.63078,
#  177.30524,
#  222.54285,
#  -7.415952,
#  150.99712,
#  2.1699255,
#  138.24323,
#  -6.9048395,
#  73.75215,
#  61.411076,
#  96.980835,
#  32.6313,
#  113.27879,
#  -4.3719234,
#  -1.4153445,
#  107.16462,
#  207.91794,
#  116.54135,
#  94.4398,
#  146.02516,
#  0.9052847,
#  182.9884,
#  81.68541,
#  130.78694,
#  -4.834421,
#  229.52081,
#  62.035793,
#  124.23907,
#  2.30188,
#  191.39963,
#  205.93825,
#  136.74455,
#  134.51639,
#  151.4684,
#  170.00557,
#  -2.9741235,
#  64.148926,
#  -2.336726,
#  37.713367,
#  151.98141,
#  -1.5065502,
#  116.89284,
#  153.87776,
#  156.89162,
#  126.706154,
#  146.81966,
#  103.87,
#  102.46055,
#  108.229805,
#  129.85419,
#  -2.8194818,
#  120.81765,
#  64.586655,
#  0.00019235312,
#  -5.687133,
#  203.22476,
#  46.336174,
#  214.17116,
#  0.11159518,
#  187.57306,
#  234.18982,
#  -2.9607904,
#  137.36528,
#  138.48105,
#  -6.0304327,
#  103.094635,
#  123.99586,
#  152.36717,
#  -1.7560929,
#  220.3568,
#  -3.6638715,
#  84.51596,
#  -4.4337597,
#  123.77805,
#  -3.4393752,
#  135.12039,
#  94.776924,
#  116.33349,
#  97.453255,
#  85.429794,
#  -5.796076,
#  107.31019,
#  148.33937,
#  92.51458,
#  127.15348,
#  65.865875,
#  37.28528,
#  153.55675,
#  81.636566,
#  121.35463,
#  3.7193604,
#  -3.3282456,
#  168.80235,
#  -7.0597343,
#  154.28421,
#  105.862144,
#  41.14295,
#  76.18926,
#  4.9610353,
#  100.756256,
#  168.8191,
#  102.97845,
#  184.71321,
#  72.68029,
#  221.17606,
#  101.25765,
#  -4.3891644,
#  146.76231,
#  -5.4923806,
#  0.104052916,
#  149.39978,
#  185.15349,
#  181.93294,
#  -5.612844,
#  -3.0902138,
#  111.53387,
#  162.36548,
#  146.13179,
#  96.65007,
#  41.89681,
#  -2.668282,
#  150.06906,
#  111.99882,
#  70.70167,
#  57.717854,
#  148.97977,
#  131.96481,
#  1.4520738,
#  142.76305,
#  86.20401,
#  -4.8480077,
#  31.455042,
#  90.13954,
#  103.42914,
#  38.89128,
#  -4.2954073,
#  109.840065,
#  162.48438,
#  70.9106,
#  145.9541,
#  136.81975,
#  181.17369,
#  142.11646,
#  93.75498,
#  107.97983,
#  156.87,
#  104.415726,
#  151.5768,
#  138.24448,
#  52.031006,
#  118.42586,
#  100.52807,
#  102.966,
#  102.3036,
#  111.46465,
#  19.747267,
#  115.76919,
#  125.28257,
#  45.097557,
#  116.0869,
#  136.37257,
#  51.060944,
#  136.92566,
#  154.41843,
#  113.986115,
#  189.68546,
#  -3.1188643,
#  101.496284,
#  146.34514,
#  126.56703,
#  171.23328,
#  -5.9687076,
#  159.03172,
#  49.458565,
#  79.70261,
#  142.41136,
#  66.857765,
#  134.9352,
#  131.14096,
#  15.489484,
#  142.97945,
#  60.702446,
#  100.14127,
#  159.83893,
#  105.38395,
#  152.99216,
#  199.62186,
#  96.526566,
#  62.29848,
#  217.3216,
#  -4.0534067,
#  157.88583,
#  70.879,
#  122.52357,
#  43.744614,
#  -2.481406,
#  160.30511,
#  48.709652,
#  2.3015862,
#  68.08086,
#  1.3635306,
#  -3.6156619,
#  120.974556,
#  146.42465,
#  160.78448,
#  120.96892,
#  75.156815,
#  -1.8994365,
#  213.92094,
#  109.54277,
#  126.77182,
#  123.3053,
#  68.88203,
#  181.18745,
#  82.32373,
#  78.71202,
#  116.97889,
#  65.28239,
#  -3.6166236,
#  47.078327,
#  91.13948,
#  187.96541,
#  -4.73868,
#  181.5982,
#  47.290676,
#  87.60506,
#  150.3713,
#  72.54138,
#  171.07286,
#  64.75058,
#  127.84465,
#  157.01834,
#  -6.264476,
#  121.60439,
#  152.0464,
#  116.92108,
#  -2.9568422,
#  141.81519,
#  -2.8394763,
#  139.71565,
#  170.19136,
#  140.95093,
#  198.00438,
#  172.28914,
#  68.32541,
#  168.74782,
#  170.42294,
#  79.45174,
#  175.56645,
#  156.59825,
#  79.63937,
#  69.63519,
#  107.72227,
#  181.81331,
#  49.24815,
#  -0.048351504,
#  142.71986,
#  151.75508,
#  127.4209,
#  44.490032,
#  164.7442,
#  124.781296,
#  143.85406,
#  -4.5967336,
#  -6.5905952,
#  43.221096,
#  135.23375,
#  97.77588,
#  33.43529,
#  155.30212,
#  106.82648,
#  164.13531,
#  164.99872,
#  74.70849,
#  148.46875,
#  124.62451,
#  139.75398,
#  56.562,
#  154.66258,
#  127.94491,
#  130.54332,
#  136.60777,
#  100.87856,
#  112.77837,
#  152.30486,
#  -0.036152266,
#  131.09692,
#  148.88878,
#  109.44731,
#  109.6877,
#  -4.22367,
#  125.33552,
#  57.495373,
#  100.15158,
#  23.90417,
#  127.59827,
#  111.66243,
#  106.67347,
#  48.14476,
#  218.48137,
#  110.2067,
#  135.76103,
#  0.40715083,
#  149.30066,
#  141.74283,
#  -3.5706108,
#  151.92627,
#  121.37102,
#  90.03924,
#  118.92282,
#  160.32658,
#  95.14224,
#  68.922615,
#  157.50775,
#  -3.8372526,
#  62.263332,
#  109.480545,
#  138.99738,
#  151.36789,
#  45.92808,
#  -4.9651504,
#  134.21571,
#  76.9193,
#  -2.8922317,
#  168.0964,
#  130.86055,
#  161.86743,
#  129.1394,
#  150.36241,
#  13.503534,
#  132.31598,
#  108.32758,
#  104.70937,
#  72.82923,
#  133.5226,
#  61.372036,
#  137.98543,
#  140.23817,
#  1.5629501,
#  56.474594,
#  5.3104343,
#  -5.512446,
#  61.08292,
#  113.97653,
#  -7.3525467,
#  2.9043703,
#  0.5486114,
#  94.61962,
#  123.01509,
#  ...]

# %%
value['predicted'] = np.array(real_output)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (100,100)

# %%
value.plot()
